# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json
r_g = requests.get('https://cat-fact.herokuapp.com/facts') # 兩個網站都 ok!
r_p = requests.post('https://cat-fact.herokuapp.com/facts')
print(type(r_g.text))
print(r_g.status_code)  #200 正常
print(r_p.status_code)
r_g,r_p
# Out:
# <class 'str'>
# 200
# 401
# (<Response [200]>, <Response [401]>)

# %%
print(type(json.loads(r.text)))
# Out:
# <class 'dict'>

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
w = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel') 
json.loads(w.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Nov 29, 2019 7:50:00 AM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Nov 29, 2019 7:50:00 AM',
#    'StationIdentifier': '2560H023',
#    'WaterLevel': 13.11},
#   {'RecordTime': 'Nov 29, 2019 7:50:00 AM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.71},
#   {'RecordTime': 'Nov 29, 2019 7:50:00 AM',
#    'StationIdentifier': '2560H025',
#    'WaterLevel': 3.19},
#   {'RecordTime': 'Nov 29, 2019 7:50:00 AM',
#    'StationIdentifier': '2560H020',
#    'WaterLevel': 0.42},
#   {'RecordTime': 'Nov 29, 2019 7:50:00 AM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.18},
#   {'RecordTime': 'Nov 29, 2019 7:50:00 AM',
#    'StationIdentifier': '2200H007',
#    'WaterLevel': 155.93},
#   {'RecordTime': 'Nov 29, 2019 7:50:00 AM',
#    'StationIdentifier': '2370H025',
# ...
